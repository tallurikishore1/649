# %% [markdown]
# <a href="https://colab.research.google.com/github/tallurikishore1/649/blob/main/7_feb_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
import pandas as pd
df=pd.read_csv(r"C:\dataset\cars.csv")

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
df.shape
# Out:
# (81, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
df.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]>

# %%
df.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
c=df['HP'].corr(df['MPG'])

# %%
c
# Out:
# -0.7250383497637913

# %%
c1=df['HP'].corr(df['VOL'])

# %%
c1
# Out:
# 0.07745947360036018

# %%
c2=df['HP'].corr(df['SP'])

# %%
c2
# Out:
# 0.9738480721866618

# %%
c3=df['HP'].corr(df['WT'])

# %%
c3
# Out:
# 0.07651306534492243

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['HP'],df['MPG'])

# %%
plt.scatter(df['HP'],df['SP'])

# %%
df.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
df.isnull()
# Out:
#        HP    MPG    VOL     SP     WT
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 76  False  False  False  False  False
# 77  False  False  False  False  False
# 78  False  False  False  False  False
# 79  False  False  False  False  False
# 80  False  False  False  False  False
#
# [81 rows x 5 columns]

# %%
sns.set_style('whitegrid')
sns.pairplot(df)

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
import statsmodels.formula.api as smf#import pandas as pd
#df=pd.read_csv(r"C:\dataset\cars.csv")
model=smf.ols('MPG~WT+VOL+SP+HP',data=df).fit()

# %%
model.params
# Out:
# Intercept    30.677336
# WT            0.400574
# VOL          -0.336051
# SP            0.395627
# HP           -0.205444
# dtype: float64

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept    2.058841
# WT           0.236541
# VOL         -0.590970
# SP           2.499880
# HP          -5.238735
# dtype: float64
#  Intercept    0.042936
# WT           0.813649
# VOL          0.556294
# SP           0.014579
# HP           0.000001
# dtype: float64

# %%
(model.rsquared, model.rsquared_adj)
# Out:
# (0.7705372737359845, 0.7584602881431416)

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('C:\dataset\Cars.csv')
df
import statsmodels.formula.api as smf
model=smf.ols('WT~VOL',data=df).fit()
model.summary()

sns.regplot(x="WT", y="VOL",data=df);

# %%
sns.regplot(x="SP", y="MPG",data=df);

# %%
sns.regplot(x="HP", y="MPG",data=df);

# %%
sns.regplot(x="VOL", y="MPG",data=df);

# %%
sns.regplot(x="WT", y="MPG",data=df);

# %%
sns.regplot(x="HP", y="SP",data=df);

# %%
sns.regplot(x="HP", y="WT",data=df);

# %%
sns.regplot(x="HP", y="VOL",data=df);

# %%
rsq_hp = smf.ols('HP~WT+VOL+SP',data=df).fit().rsquared
vif_hp=1/(rsq_hp)

# %%
plt.show()

# %%
import statsmodels.api as sm

# %%
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>10))
# Out:
# [array([], dtype=int64)]

# %%
def get_standardized_values(vals):
    return (vals-vals.mean()/vals.std())

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
           get_standardized_values(model.resid))
plt.title('Residual Plot')
plt.xlabel("Standardized Fitted values")
plt.ylabel("Standardized residual values")
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'VOL',fig=fig)
plt.show()

# %%
model_influence = model.get_influence()
(c, _) = model_influence. cooks_distance

#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df)), np.round(c, 3))
plt.xlabel('Row index' )
plt.ylabel('Cooks Distance' )
plt. show()

# %%
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
final_ml_V=smf.ols('MPG~VOL+SP+HP',data=df).fit()

# %%
final_ml_V.rsquared
# Out:
# 0.770368341321302

# %%
final_ml_V.aic
# Out:
# 475.9875158854609

# %%
final_ml_w=smf.ols('MPG~WT+SP+HP',data=df).fit()

# %%
final_ml_w.rsquared
# Out:
# 0.769482813998346

# %%
final_ml_w.aic
# Out:
# 476.29927501529767

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()
car1=df.drop(df.index[[70,76]],axis=0).reset_index()
car1=car1.drop(['index'],axis=1)

# %%
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf

# %%
final_ml_V= smf.ols('MPG~VOL+SP+HP',data = car1).fit()

# %%
(final_ml_V.rsquared,final_ml_V.aic)
# Out:
# (0.8161692010376008, 446.1172263944772)

# %%
final_ml_W= smf.ols('MPG~WT+SP+HP',data = car1).fit()

# %%
(final_ml_W.rsquared, final_ml_W.aic)
# Out:
# (0.8160034320495304, 446.18843235750313)

# %%
pred_y=final_ml_V.predict(df)

# %%
y=pd.DataFrame(pred_y)

# %%
y
# Out:
#             0
# 0   44.053224
# 1   42.694424
# 2   42.694424
# 3   42.790029
# 4   42.711109
# ..        ...
# 76  17.510844
# 77  16.491552
# 78  23.080092
# 79  10.371281
# 80  13.670311
#
# [81 rows x 1 columns]

# %%
data=pd.read_csv(r'C:\dataset\Toyoto_Corrola.csv')

# %%
data
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     ÊTOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04     KM   HP  Doors  Cylinders  Gears  Weight
# 0            23  46986   90      3          4      5    1165
# ...

# %%
final_= smf.ols('Price~Age_08_04+KM+HP++Weight',data = data).fit()

# %%
final_.rsquared
# Out:
# 0.8617758687562083

# %%
final_.aic
# Out:
# 24781.867951448934

# %%
pred_y1=final_.predict(data)

# %%
pred_y1
# Out:
# 0       16555.144943
# 1       16045.276927
# 2       16536.360171
# 3       16167.949137
# 4       15957.560290
#             ...
# 1431     8727.825040
# 1432     8205.568443
# 1433     8366.973226
# 1434     8491.362429
# 1435    10648.891443
# Length: 1436, dtype: float64

# %%
pd.DataFrame(pred_y1)
# Out:
#                  0
# 0     16555.144943
# 1     16045.276927
# 2     16536.360171
# 3     16167.949137
# 4     15957.560290
# ...            ...
# 1431   8727.825040
# 1432   8205.568443
# 1433   8366.973226
# 1434   8491.362429
# 1435  10648.891443
#
# [1436 rows x 1 columns]

# %%
final_n= smf.ols('Price~Age_08_04+KM+Model+HP++Weight',data = data).fit()

# %%
final_n

# %%
final_n.rsquared
# Out:
# 0.9546806411892897

# %%
final_n.aic
# Out:
# 23920.523724821785

# %%
pred_y1=final_.predict(data)

# %%
pred_y1
# Out:
# 0       14584.263139
# 1       14146.309923
# 2       13950.000000
# 3       14328.251060
# 4       13882.103536
#             ...
# 1431     9637.639150
# 1432     8797.348447
# 1433     8910.463965
# 1434     8991.784799
# 1435     8206.321351
# Length: 1436, dtype: float64
